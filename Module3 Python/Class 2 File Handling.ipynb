# %% [markdown]
# # CLASS 4 FILE HANDLING

# %%
#Basic Read the CSV File
import csv

with open('/Volumes/data-bootcamp/default/module2class2_global_food-wastage/global_food_wastage_dataset.csv',mode='r') as file:
    reader=csv.reader(file)
    
    #next is used when you want to skip the header of the csv
    next(reader)
    for row in reader:
        print(row)

# %%
import csv

#only use some part of this code 
with open('/Volumes/data-bootcamp/default/module2class2_global_food-wastage/global_food_wastage_dataset.csv',mode='r') as file:
    #This wil read file as a dictionary
    reader=csv.DictReader(file)

    for row in reader:
        print(row)

# %%
import csv

#only use some part of this code 
with open('/Volumes/data-bootcamp/default/module2class2_global_food-wastage/global_food_wastage_dataset.csv',mode='r') as file:
    #This wil read file as a dictionary
    reader=csv.DictReader(file)

    for row in reader:
        #extracting only country from the dataset
        print(row['Country'])

# %% [markdown]
# ### **Writing to a CSV**

# %%
# write an output file 
with open('output.csv', mode= 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Country', 'City'])

# %%
#Reading the log file line by line nad creating a basic logging system
with open('log.txt', mode = 'r') as file:
    count = 1
    for line in file:
        if "ERROR" in line:
            print(f"ALERT occured in line {count}: {line.strip()}")
        count+=1

# %%
#Fetching Data from API

import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/mcenter/v1/41881/comm"

headers = {
	"x-rapidapi-key": "735d1841c7msh5908b4d65739c2ap1c43c0jsnff541268d977",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())

# %% [markdown]
# ## 🧪 MINI PROJECT: File + API + Logic
# **✅ Task:
# **
# - Fetch users from API
# - Filter users from a specific city
# - Write to a CSV

# %%
import requests, csv

response = requests.get('https://jsonplaceholder.typicode.com/users')
if response.status_code ==200:
    users = response.json()

    #this is how we check what data we want as the data is in form of list 
    #print(users[0]['address']['city'])

    with open('city_users.csv',mode= 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Name', 'City'])
     
        for user in users:
            if user['address']['city'] == 'South Christy':
                writer.writerow([user['name'], user['address']['city']])
else:
    print("Failed to fetch data")
